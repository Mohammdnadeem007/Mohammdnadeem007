# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammdnadeem007/Mohammdnadeem007/blob/main/Retail_Banking_Sales_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Mohammdnadeem007/Retail-Banking-Sales-Analytics.git
# Out:
# Cloning into 'Retail-Banking-Sales-Analytics'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 99 (delta 36), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (99/99), 31.64 KiB | 809.00 KiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# %cd Retail-Banking-Sales-Analytics
# Out:
# /content/Retail-Banking-Sales-Analytics

# %%
# !pwd
# Out:
# /content/Retail-Banking-Sales-Analytics

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !ls
# Out:
# assets	data  LICENSE  notebooks  README.md  reports  src
